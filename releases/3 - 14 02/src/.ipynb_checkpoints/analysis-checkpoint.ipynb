# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
from scipy import fftpack
from numpy import savetxt
from scipy.signal import lfilter, firwin

# %%
fpga_sig = [0
251
15
253
24
128
108
128
246
0
251
15
253
24
128
108
128
246
0
251
15
253
24
128
108
128
246
0
251
15
253
24
128
108
128
246
0
251
15
253
24
128
108
128
246
0
251
15
253
24
128
108
128
246
0
251
15
253
24
128
108
128
246
0
251
15
253
24
128
108
128
246
0
251
15
253
24
192
108
192
246
0
251
15
253
24
192
108
192
246
0
251
15
253
24
192
108
192
246
0
251
15
253
24
192
108
192
246
0
251
15
253
24
192
108
192
246
0
251
15
253
24
192
108
192
246
0
251
15
253
24
192
108
192
246
0
251
15
253
24
192
108
192
246
0
251
15
253
24
192
108
192
246
0
251
15
253
24
128
108
128
246
0
251
15
253
24
128
108
128
246
0
251
15
253
24
128
108
128
246
0
251
15
253
24
128
108
128
246
0
251
15
253
24
128
108
128
246
0
251
]

# %% [markdown]
# ## Getting the coefficients

# %%
numtaps = 3 #the higher it is, the more precise

# %%
f = 0.1

c = signal.firwin(numtaps, f)
#print(c)

# %% [markdown]
# The trasformation law is:
# $$Y[n]=C_0X[n]+C_1X[n-1]+C_2X[n-2]+C_3X[n-3]$$

# %%
signal = np.loadtxt("input.txt", dtype=np.int)

# %%
filtered_signal = lfilter(c, 1.0, signal)
time_vec = np.arange(signal.size)

# %%
plt.figure(figsize=(25, 5))
plt.scatter(time_vec, filtered_signal, alpha=0.5)
plt.scatter(time_vec+1, signal, alpha =0.5,color='r')

# %% [markdown]
# ## Confonting Python results with FPGA's

# %%
fpga = np.loadtxt("output.txt", dtype=np.int)

# %%
if (-np.amin(signal)>np.amax(signal)):
    norm = np.amin(signal)
else:
    norm = np.amax(signal)

fmin = -np.amin(fpga)
fmax = np.amax(fpga)
if (fmin > fmax):
    fnorm = fmin
else:
    fnorm = fmax

fpga = norm * fpga/(fnorm)

# %%
plt.figure(figsize=(25, 5))
plt.scatter(time_vec, filtered_signal, alpha=0.5)
plt.scatter(time_vec, fpga, alpha =0.5,color='r')

# %%
#print(fpga)

# %%
#print(filtered_signal)

# %%
diffs =(np.abs(filtered_signal-fpga))

# %%
diffs
# Out:
# array([0.        , 0.13598033, 1.21836321, 1.21489009, 2.01091959,
#        1.0198525 , 2.35980333, 1.76774434, 2.01091959, 1.39900809,
#        0.30421919, 1.11811451, 0.33796415, 2.93945631, 0.43672641,
#        1.59404568, 0.18263157, 1.41687391, 2.12357431, 0.30223251,
#        1.73002601, 1.39206186, 2.08784267, 0.76923077, 0.0054598 ,
#        1.58511277, 0.64764314, 1.59057257, 0.58858588, 0.85707344,
#        1.30074608, 0.22183632, 1.2094303 , 0.24516194, 1.15930595,
#        0.64764314, 0.30769231, 0.37568247, 0.86054655, 0.52059572,
#        0.23076923, 0.88387217, 0.13052054, 0.28982649, 0.00893291,
#        0.42580682, 0.42580682, 0.48486408, 0.52952863, 0.10372181,
#        0.87841237, 0.05558414, 1.45806535, 1.50818969, 0.12357431,
#        0.67444187, 0.35235686, 0.71910642, 0.96426836, 2.23275591,
#        0.19156448, 0.03771832, 1.64417003, 0.86401967, 1.        ,
#        1.27196067, 0.76923077, 0.34541063, 1.45806535, 1.05012435,
#        0.08238287, 2.20049739, 0.97320127, 0.47245805, 1.08238287,
#        0.06799017, 0.01786582, 1.25409485, 0.28089358, 0.38114227,
#        1.32208501, 0.95186233, 2.28834005, 2.74987851, 1.67642855,
#        0.94640254, 0.11811451, 0.97866106, 0.37220936, 0.47047137,
#        1.63523712, 0.72456622, 0.56724695, 1.06997685, 1.0054598 ,
#        0.23970214, 0.6119115 , 0.04119144, 0.83374782, 0.46153846])

# %%
import random
import math

sig = []
for i in range(200):
    temp = ((math.sin(i/20)+1)*120/2+random.randrange(-100, 100)/5+10)
    if (temp > 155):
        temp = 155
    if (temp < 0):
        temp = 0
    sig.append(int(temp))
print(max(sig))
print(min(sig))
# Out:
# 148
# 0

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(len(sig))
plt.scatter(x,sig)
